# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (100,100)
plt.rcParams.update({'font.size': 15})
plt.style.use('ggplot')
import os

# %%
#plt.style.available

# %%
ROOT = "../data/"

# %%
PATH = os.listdir("../data")

# %%
PATH = [p for p in PATH if pd.read_csv(ROOT+p,index_col=0).shape[0]>0]

# %%
left  = 0.125  # the left side of the subplots of the figure
right = 0.9    # the right side of the subplots of the figure
bottom = 0.1   # the bottom of the subplots of the figure
top = 0.9      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 0.2

# %%
fig, axi = plt.subplots(nrows=len(PATH)//2,ncols=2,figsize=(40,60), sharex=False, sharey=False)
fig.subplots_adjust(left=0.2, bottom=1, right=2, top=2, wspace=2, hspace=2)
#plt.tight_layout() # Or equivalently,  "plt.tight_layout()"
plt.show()

# %%
fig, axi = plt.subplots(len(PATH)//2,2,figsize=(20,20), sharex=True, sharey=True)
fig.subplots_adjust(hspace=4)
indx = 0
while indx<len(PATH)//2:
    title1 = PATH[indx].split(".")[0]
    title2 = PATH[indx+1].split(".")[0]
    data1 = pd.read_csv(ROOT+ PATH[indx],index_col=0)
    data1 = data1.iloc[::-1]
    data2 = pd.read_csv(ROOT+ PATH[indx+1],index_col=0)
    data2 = data2.iloc[::-1]
    data1.plot(ax=axi[indx][0],title="Covid-19 "+title1+" Trend (Created by DataPivotAfrica)",linewidth=2, marker="o")
    data2.plot(ax=axi[indx][1],title="Covid-19 "+title1+" Trend (Created by DataPivotAfrica)",linewidth=2, marker="o")
    indx = indx+1
    if indx>3: break
